# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/CV_2/'
# Out:
# /content/drive/MyDrive/CV_2

# %%
# !pip install ultralytics

# %%
'''from ultralytics.data.converter import convert_dota_to_yolo_obb
convert_dota_to_yolo_obb('/content/drive/MyDrive/CV_2/dataset')'''
# Out:
# "from ultralytics.data.converter import convert_dota_to_yolo_obb\nconvert_dota_to_yolo_obb('/content/drive/MyDrive/CV_2/dataset')"

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.yaml')
results = model.train(data='output_yolo_oriented_preprocessing.yaml', epochs=100, imgsz=1024, batch = 16)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# !ls
# Out:
# dataset		      output_yolo_oriented_preprocessing.yaml  yolov8n.pt
# Model_Training.ipynb  runs				       yolov8n.yaml

# %%
model.predict('dataset/images/val/', save=True)
# Out:
# image 1/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_0.png: 1024x1024 (no detections), 9.4ms
# image 2/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_1.png: 1024x1024 1 ship, 1 large-vehicle, 5 small-vehicles, 18.4ms
# image 3/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_2.png: 1024x1024 13 small-vehicles, 10.2ms
# image 4/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_3.png: 1024x1024 1 small-vehicle, 10.1ms
# image 5/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_4.png: 1024x1024 1 plane, 10.1ms
# image 6/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_5.png: 1024x1024 (no detections), 9.8ms
# image 7/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_6.png: 1024x1024 3 small-vehicles, 10.3ms
# image 8/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_7.png: 1024x1024 (no detections), 9.5ms
# image 9/180 /content/drive/MyDrive/CV_2/dataset/images/val/P2755_8.png: 1024x1024 (no detections), 10.5ms
# ...
